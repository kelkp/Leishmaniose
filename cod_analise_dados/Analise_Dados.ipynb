# %%
import pyodbc
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##Ler Dados do ACCESS

# %%
import pyodbc

conn = pyodbc.connect(r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ= content\\drive\\My Drive\\Colab\\Lab_IV\\BD\\EstudoLeishmaniose.accdb;')
cursor = conn.cursor()
cursor.execute('select * from View_CasosPorAno')
for row in cursor.fetchall():
    print (row)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-7-498042e0cab3> in <module>()
#       1 import pyodbc
#       2
# ----> 3 conn = pyodbc.connect(r'Driver={Microsoft Access Driver (*.mdb, *.accdb)};DBQ= content\\drive\\My Drive\\Colab\\Lab_IV\\BD\\EstudoLeishmaniose.accdb;')
#       4 cursor = conn.cursor()
#       5 cursor.execute('select * from View_CasosPorAno')
#
# Error: ('01000', "[01000] [unixODBC][Driver Manager]Can't open lib 'Microsoft Access Driver (*.mdb, *.accdb)' : file not found (0) (SQLDriverConnect)")

# %%
DBFile = r'/content/drive/My Drive/Colab/Lab_IV/BD/EstudoLeishmaniose.accdb'

conn = pyodbc.connect('DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};DBQ='+DBFile)
curs = conn.cursor()

SQL = 'SELECT * FROM mytable;' # insert your query here
curs.execute(SQL)

rows = curs.fetchall()

curs.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-12-f227869b4c47> in <module>()
#       1 DBFile = r'/content/drive/My Drive/Colab/Lab_IV/BD/EstudoLeishmaniose.accdb'
#       2
# ----> 3 conn = pyodbc.connect('DRIVER={Microsoft Access Driver (*.mdb, *.accdb)};DBQ='+DBFile)
#       4 curs = conn.cursor()
#       5
#
# Error: ('01000', "[01000] [unixODBC][Driver Manager]Can't open lib 'Microsoft Access Driver (*.mdb, *.accdb)' : file not found (0) (SQLDriverConnect)")
